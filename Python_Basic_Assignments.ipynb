# %%
#Q1.explain the key features of python that make it a popular choice of programming

Ans: Python is a highly popular programming language. Several key features contribute to its widespread adoption:
1. Readability and Simplicity
Clean Syntax: Python’s syntax is clear and easy to understand, which makes it an excellent choice for beginners and professionals alike. 
Indentation: Python uses indentation to define the structure of code.

2. Versatility
General-Purpose Language: Python is not limited to a specific domain and can be used for web development, data analysis, artificial intelligence, machine learning, automation, scripting, and more.
Cross-Platform Compatibility: Python is available on various operating systems like Windows, macOS, and Linux, making it highly portable.

3.Interpreted Language: 
Python code is executed line-by-line, which simplifies debugging.

4.Dynamic Typing:

 Variables in Python are not explicitly typed, allowing flexibility in coding.

5.Extensive Libraries: 

Python has a vast standard library and many third-party libraries, supporting tasks like web development, data analysis, and machine learning.

6.Cross-Platform Compatibility: 

Python runs on various operating systems without requiring changes to the code.

7.Community Support: 

Python has a large and active community, offering plenty of resources and tools for development.

# %%
#Q2 Describe the role of predefined keywords in python and provide examples of how they are used in a program in precise.

Ans:Predefined keywords in Python are reserved words that have specific meanings and purposes. They cannot be used as identifiers (e.g., variable names).

Examples of keywords include if, else, while, for, def, class, import, try, except, return, True, False, None, etc.

If, else, elif:
    
    if x>0:
        print("positve")
    elif x==0:
        print("Zero")
    else:
        print("Negative")

for, while:
    
    for i in range(5):
    print(i)
    
Def:
    
    def greet(name):
    return f"Hello, {name}"

# %%
# Q3: compare and contrast mutable and immutable objects in python with exmples.

Ans: Objects are classified into two types 
1.Mutable
2.Immutable

Mutable Objects: Objects whose state can be modified after creation.

Immutable Objects: Objects whose state cannot be modified after creation. Any change creates a new object.

Examples :
    
    List:
        
    my_list = [1,2,3,4]
    my_list[2]=10
    print(my_list)
    
Immutable:
    
    String:
        
        My_string ="hello"
        new_string = My_string.upper()
        print(My_string)
        
    Tuples
    
        my_tup = (1, 4, 6)
        my_tup[0] = 10

# %%
#Q4 discuss the different types of operator in python and provide examples of how they used

Ans: Python has several types of operators that are used to perform operations on variables and values.

1. Arithmetic Operators

Perform basic mathematical operations.

Example:
    
a= 10
b = 3
print(a + b)  # Addition, Output: 13
print(a - b)  # Subtraction, Output: 7
print(a * b)  # Multiplication, Output: 30
print(a / b)  # Division, Output: 3.3
print(a % b)  # Modulus, Output: 1
print(a ** b) # Exponentiation

2. Comparison Operators

Compare two values and return a boolean result.

a = 10
b = 5
print(a == b)  # Equal, Output: False
print(a != b)  # Not equal, Output: True
print(a > b)   # Greater than, Output: True
print(a < b)   # Less than, Output: False
print(a >= b)  # Greater than or equal to, Output: True
print(a <= b)  # Less than or equal to, Output : false

3. Logical Operators

Combine conditional statements.

a = True
b = False
print(a and b)  # Logical AND, Output: False
print(a or b)   # Logical OR, Output: True
print(not a)    # Logical NOT,

4. Assignment Operators

Assign values to variables with optional arithmetic.

a = 10
a += 5  # Output: 15
a -= 2  # Output: 13
a *= 3  # Output: 39
a /= 3


5. Bitwise Operators

 Perform bit-level operations on binary numbers.
    
a = 10 
b = 4  
print(a & b)  # Bitwise AND, Output: 0
print(a | b)  # Bitwise OR, Output: 14
print(a ^ b)  # Bitwise XOR, Output: 14
print(~a)     # Bitwise NOT, Output: -11
print(a << 1) # Bitwise left shift, Output: 20
print(a >> 1) # Bitwise right shift, Output: 5
    
6. Identity Operators

 Check if two variables reference the same object.
    
a = [1, 2, 3]
b = a
c = [1, 2, 3]
print(a is b)   # Output: True
print(a is c)   # Output: False
print(a is not c)  # Output: True

7. Membership Operators

Test if a sequence contains a specified value.

a = [1, 2, 3]
print(2 in a)     # Output: True
print(5 in a)     # Output: False
print(6 not in a) # Output: True

# %%
#Q5 Explain the concept of typecasting in python with examples ?

Ans: Typecasting resfers to converting one data type to another. Built in function such as int(), float(), str(), and list().
used for conversion 

Examples 

Integer to String 

num =6;
Str_num = str(num)

print(Str_num)  #output : '6'
print(type(str_num))  # output: <String>

String to Integer:
    
str_num = "14"
num = int(str_num)
print(num)              # Output: 14
print(type(num))        # Output: <int'>

List to Tuple:
    
lst = [1, 2, 3]
tpl = tuple(lst)
print(tpl)              # Output: (1, 2, 3)
print(type(tpl))        # Output: <class 'tuple'>

# %%
#Q6 How do conditional statement work in python illustrate with example.

Ans: Conditional statements in Python allow you to execute specific blocks of code based on certain conditions.
for Example if, elif, and else.

Example

age = 20

if age < 18:
    print("You are a minor.")
elif age >= 18 and age < 65:
    print("You are an adult")
else:
    print("You are old senior citizen.")
    
Output:
    
You are a adult.

# %%
#Q7 Describe the different types of loops in python and their use cases with examples

Ans: In Python, loops are used to execute a block of code repeatedly based on certain conditions. There are mainly two types of loops in Python: for loops and while loops. 

Use case 1:
    
    for Loop:
    
    for variable in iterable:
        #code execution
        
Use case 2:
    Iteration in list:
        
    fruits = ["apple", "banana", "cherry"]
    for fruit in fruits:
        print(fruit)
        
Use case 3: using range() function.

    for i in range(5):
    print(i
          
2. while Loop
          
    The while loop repeatedly executes a block of code as long as a given condition is True.
          
Use case 1: Basic While Loop:
          
          count = 0
while count < 5:
    print(count)
    count += 1
          
Use case 2: With Break Statement
          
    for i in range(10):
        if i == 5:
        break
    print(i)
          
Use case 3: With continue Statement
          
        for i in range(10):
            if i % 2 == 0:
                continue
        print(i)
